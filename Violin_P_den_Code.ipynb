# %%
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# Use seaborn style
sns.set()

# Read CSV from GitHub raw URL
url = 'https://raw.githubusercontent.com/SIslam007/Proteomics-projects/refs/heads/main/violin_Pden.csv'
df = pd.read_csv(url)


print(df.keys())
print(df.shape)
df



df.dropna(inplace = True)
print(df.head())


plt.title("Violin Plot")
plt.ylabel("Ovserved Values")
ax = sns.violinplot(data=df,palette=['#E9967A','#2F4F4F','#33A1C9','#483D8B','#9FB6CD','#8B4789'],edgecolor="gray")
plt.savefig("violin_Pden.pdf")
plt.show()
# Out:
# Index(['WT_1', 'WT_2', 'WT_3', 'hnox_1', 'hnox_2', 'hnox_3'], dtype='object')
# (2694, 6)
#         WT_1       WT_2       WT_3     hnox_1     hnox_2     hnox_3
# 0  15.257661  15.466992  15.106084  15.163709  15.350200  15.330972
# 1  19.323959  19.185708  19.439069  18.638041  18.898438  18.546545
# 2  17.310870  17.453550  17.548070  17.745923  17.844168  17.708122
# 3  20.292848  20.373691  20.448830  20.301087  20.528667  20.162374
# 4  19.390807  19.493019  19.472492  19.444374  19.413354  19.539371
